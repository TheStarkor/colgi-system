# %%
import pandas as pd

# %%
dataset = pd.read_csv("for_visualization_food.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0               a dog laying next to a birthday cake
# 1           1  a black and white dog standing next to a birth...
# 2           2       a dog laying on a table with a birthday cake
# 3           3          a dog laying on the ground next to a cake
# 4           4      a dog sitting at a table with a plate of food
#
#                    prompt  group_num  image_num  \
# 0  a dog is eating a cake          0          0
# 1  a dog is eating a cake          0          1
# 2  a dog is eating a cake          0          2
# 3  a dog is eating a cake          0          3
# 4  a dog is eating a cake          0          4
#
#                                               vector          x          y
# 0  [-3.15368325e-01  1.65492833e+00 -3.76081681e+... -22.215971  27.099045
# 1  [-1.9701213   1.573011   -4.1248627  -0.875087...  -9.566553  41.481700
# ...

# %%
dataset= dataset.loc[dataset['prompt']=='a dog is eating a cheese cake']
dataset.head()
# Out:
#       Unnamed: 0                                               text  \
# 3200        3200  a dog looking at a cheesecake with strawberrie...
# 3201        3201  a dog is looking at a cake with strawberries o...
# 3202        3202  a dog with a piece of cheese and strawberries ...
# 3203        3203            a dog eating a piece of cake on a table
# 3204        3204  a dog sitting on a table eating a piece of che...
#
#                              prompt  group_num  image_num  \
# 3200  a dog is eating a cheese cake          4          0
# 3201  a dog is eating a cheese cake          4          1
# 3202  a dog is eating a cheese cake          4          2
# 3203  a dog is eating a cheese cake          4          3
# 3204  a dog is eating a cheese cake          4          4
#
#                                                  vector          x           y
# 3200  [ 7.27219999e-01  1.64846003e+00 -1.97036004e+... -11.821568 -101.590880
# ...

# %%
for i,row in dataset.iterrows():
    if i<3220: print(row['text'])
# Out:
# a dog looking at a cheesecake with strawberries on it
# a dog is looking at a cake with strawberries on it
# a dog with a piece of cheese and strawberries on a plate
# a dog eating a piece of cake on a table
# a dog sitting on a table eating a piece of cheesecake
# a black and white dog eating a piece of cheese and a strawberry
# a dog looking at a cake with berries on it
# a dog sitting in front of a plate with a piece of cake on it
# a brown and white dog standing next to a plate of food
# a dog sniffing a cheesecake on a table
# a dog licking a piece of cake on a table
# a slice of cheesecake with raspberries on a white plate
# a black and white dog with a piece of cheese on a plate
# a dog is looking at a piece of cake on a plate
# a dog laying on a bed next to a piece of cheesecake
# a piece of cheese and a piece of cheese on a plate
# a dog looking at a plate of cheese and a piece of cake
# a piece of cheesecake on a plate with a flower
# ...
